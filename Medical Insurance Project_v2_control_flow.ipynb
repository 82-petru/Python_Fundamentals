# %% [markdown]
# # Medical Insurance Project

# %% [markdown]
# - In this project, you will examine how factors such age, sex, BMI num of children amd smoking status contribute to the medical insurance cost.
# - you will apply the knowledge of Python control flow to write code that gives people advice how to lower their medical insurance cost

# %% [markdown]
# **Setting up the factors**
# - first step is to create the variables for each factor.
#         age: age of the individual in years
#         sex: 0 for female, 1 for male*
#         bmi: individual’s body mass index
#         num_of_children: number of children the individual has
#         smoker: 0 for a non-smoker, 1 for a smoker

# %% [markdown]
# **Setting up the formula**
# - insurance_cost=250∗age−128∗sex+370∗bmi+425∗num_of_children+24000∗smoker−12500

# %% [markdown]
# **Analyzing Smoker status**
# - in general insurance cost are higher for smokers as well as people with higher BMI
# - create a function that analyzes an individual's smoking status
# - inside the function write in an if/else statement
# - call the function

# %%
def analyze_smoker(smoker_status):
    if smoker_status == 1:
        print("To lower your cost, you should consider quitting smoking.")
    else:
        print("Smoking is not an issue for you.")

# %% [markdown]
# **Analyzing Smoker status**

# %%
def estimate_insurance_cost(name, age, sex, bmi, num_of_children, smoker):
  estimated_cost = 250*age - 128*sex + 370*bmi + 425*num_of_children + 24000*smoker - 12500
  print(name + "'s Estimated Insurance Cost: " + str(estimated_cost) + " dollars.")
  analyze_smoker(smoker)
  return estimated_cost

# %%
# Estimate Keanu's insurance cost
keanu_insurance_cost = estimate_insurance_cost(name = 'Keanu', age = 29, sex = 1, bmi = 26.2, num_of_children = 3, smoker = 1)
# Out:
# Keanu's Estimated Insurance Cost: 29591.0 dollars.
# To lower your cost, you should consider quitting smoking.

# %% [markdown]
# **Analyzing BMI**
# - define a function called analyze_bmi() that take an imput bmi_value
# - inside the function we'll want to notify whether their BMI can be improved, printing a personalized mesage
# - write if/elif/else statements
# - call the function

# %%
def analyze_bmi(bmi_value):
    if bmi_value > 30:
        print("Your BMI is in the obese range. To lower your cost, you should significantly lower your BMI")
    elif bmi_value >= 25 and bmi_value <=30:
        print("Your BMI is in the overweight range. To lower your cost, you should lower your BMI.")
    elif bmi_value >= 18.5 and bmi_value < 25:
        print("Your BMI is in a healthy range.")
    else:
        print("Your BMI is in the underweight range. Increasing your BMI will not help lower your cost, but it will help improve your health.")

# %%
def estimate_insurance_cost(name, age, sex, bmi, num_of_children, smoker):
  estimated_cost = 250*age - 128*sex + 370*bmi + 425*num_of_children + 24000*smoker - 12500
  print(name + "'s Estimated Insurance Cost: " + str(estimated_cost) + " dollars.")
  analyze_bmi(bmi)
  return estimated_cost

# %%
# Estimate Keanu's insurance cost
keanu_insurance_cost = estimate_insurance_cost(name = 'Keanu', age = 29, sex = 1, bmi = 26.2, num_of_children = 3, smoker = 1)
# Out:
# Keanu's Estimated Insurance Cost: 29591.0 dollars.
# Your BMI is in the overweight range. To lower your cost, you should lower your BMI.

# %% [markdown]
# **Analyze your own insurance cost**

# %%
def analyze_bmi(bmi_value):
    if bmi_value > 30:
        print("Your BMI is in the obese range. To lower your cost, you should significantly lower your BMI")
    elif bmi_value >= 25 and bmi_value <=30:
        print("Your BMI is in the overweight range. To lower your cost, you should lower your BMI.")
    elif bmi_value >= 18.5 and bmi_value < 25:
        print("Your BMI is in a healthy range.")
    else:
        print("Your BMI is in the underweight range. Increasing your BMI will not help lower your cost, but it will help improve your health.")

# %%
def analyze_smoker(smoker_status):
    if smoker_status == 1:
        print("To lower your cost, you should consider quitting smoking.")
    else:
        print("Smoking is not an issue for you.")

# %%
def estimate_insurance_cost(name, age, sex, bmi, num_of_children, smoker):
  estimated_cost = 250*age - 128*sex + 370*bmi + 425*num_of_children + 24000*smoker - 12500
  print(name + "'s Estimated Insurance Cost: " + str(estimated_cost) + " dollars.")
  analyze_bmi(bmi)
  analyze_smoker(smoker)
  return estimated_cost

# %%
# Estimate Petru's insurance cost
petru_insurance_cost = estimate_insurance_cost(name = 'Petru', age = 37, sex = 1, bmi = 20.9, num_of_children = 1, smoker = 0)
# Out:
# Petru's Estimated Insurance Cost: 4780.0 dollars.
# Your BMI is in a healthy range.
# Smoking is not an issue for you.
# Wall time: 0 ns

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# [link text](https://calendar.google.com/calendar/u/0/r/month/2020/11/1):

# %% [markdown]
# $$ Clasification Rate = \frac1N \sum_{i=0}^n I(y_i = \hat{y_i}) $$
# $$ standardDeviation = \sqrt[n]{\sin(variance)} $$

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %pwd
# Out:
# 'C:\\Users\\uidr1019'
